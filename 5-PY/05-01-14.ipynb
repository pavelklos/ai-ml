# %% [markdown]
# # Using pip and Package Management in Python
#
# This notebook provides a comprehensive overview of Python package management with pip, covering installation, dependency management, virtual environments, and best practices.

# %% [markdown]
# ## 1. Understanding Package Management
#
# ### What are Python Packages?
#
# Python packages are collections of modules that extend Python's functionality. They allow developers to:
# - Reuse code across projects
# - Access community-developed tools and libraries
# - Organize code in a modular way
#
# ### The Python Package Index (PyPI)
#
# [PyPI](https://pypi.org/) is the official repository for Python packages with over 400,000 projects available for installation.
#
# ### Package Management Benefits
#
# Effective package management helps you:
# - Track project dependencies
# - Create reproducible environments
# - Avoid version conflicts
# - Share code and dependencies consistently

# %% [markdown]
# ## 2. Introduction to pip
#
# `pip` is Python's standard package manager and comes pre-installed with Python 3.4 and newer. It provides a command-line interface for installing and managing Python packages.

# %%
# Check if pip is installed and verify its version
# !python -m pip --version
# Out:
# pip 25.1 from C:\Users\pavel\projects\ai-ml\.venv\Lib\site-packages\pip (python 3.13)

# %% [markdown]
# ### Updating pip
#
# It's a good practice to keep pip updated to the latest version to ensure compatibility with newer packages and security fixes.

# %%
# Update pip to the latest version
# !python -m pip install --upgrade pip

# %% [markdown]
# ## 3. Installing Packages with pip
#
# ### Basic Package Installation
#
# The most common use of pip is to install packages from PyPI.

# %%
# Install a package (requests is a popular HTTP library)
# !pip install requests

# %%
# Let's verify that the package installed correctly
import requests

response = requests.get('https://httpbin.org/get')
print(f"Status Code: {response.status_code}")
print(f"Response: {response.json()}")
# Out:
# Status Code: 200
# Response: {'args': {}, 'headers': {'Accept': '*/*', 'Accept-Encoding': 'gzip, deflate, br, zstd', 'Host': 'httpbin.org', 'User-Agent': 'python-requests/2.32.3', 'X-Amzn-Trace-Id': 'Root=1-680dd5fa-2563fe8f7c17b7805f50af87'}, 'origin': '176.222.226.7', 'url': 'https://httpbin.org/get'}

# %% [markdown]
# ### Installing Specific Versions
#
# Sometimes you need a specific version of a package for compatibility reasons.

# %%
# Install a specific version of a package
# !pip install numpy==1.22.3

# %%
# Verify the installed version
import numpy as np
print(f"Installed NumPy version: {np.__version__}")
# Out:
# Installed NumPy version: 2.2.4

# %% [markdown]
# ### Using Version Specifiers
#
# pip supports various version specifiers:

# %%
# Examples of version specifiers (shown as comments to prevent execution)

# Install version 2.x.x (minimum 2.0.0, less than 3.0.0)
# !pip install 'pandas>=2.0.0,<3.0.0'

# Install the latest version but at least 4.10.0
# !pip install 'matplotlib>=4.10.0'

# Install any version except 1.2.3
# !pip install 'requests!=1.2.3'

# %% [markdown]
# ### Installing from Alternative Sources
#
# While PyPI is the default, pip can install packages from various sources.

# %%
# Install from a GitHub repository (commented out to avoid execution)
# !pip install git+https://github.com/username/repository.git

# Install from a local directory
# !pip install -e /path/to/local/package

# Install from a .whl file
# !pip install /path/to/package.whl

# %% [markdown]
# ## 4. Managing Installed Packages
#
# ### Listing Installed Packages
#
# Let's see what packages are already installed in the current environment.

# %%
# List all installed packages
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# altair                    5.5.0
# anyio                     4.9.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# autopep8                  2.3.2
# babel                     2.17.0
# beautifulsoup4            4.13.3
# bleach                    6.2.0
# blinker                   1.9.0
# branca                    0.8.1
# Brotli                    1.1.0
# build                     1.2.2.post1
# category_encoders         2.8.1
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.4.1
# click                     8.1.8
# cloudpickle               3.1.1
# colorama                  0.4.6
# colorcet                  3.1.0
# colorspacious             1.1.2
# comm                      0.2.2
# ...

# %%
# Show details about a specific package
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\pavel\projects\ai-ml\.venv\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: dash, dtale, folium, jupyterlab_server

# %% [markdown]
# ### Updating Packages
#
# Keeping packages up-to-date ensures you have the latest features and security fixes.

# %%
# Update a specific package
# !pip install --upgrade requests

# %% [markdown]
# ### Uninstalling Packages

# %%
# Install a temporary package for demonstration
# !pip install cowsay
# Out:
# ...
#   Using cached cowsay-6.1-py3-none-any.whl.metadata (5.6 kB)
# Using cached cowsay-6.1-py3-none-any.whl (25 kB)
# ...

# %%
# Try out the package
import cowsay
cowsay.cow('This package will be uninstalled soon!')
# Out:
#   ______________________________________
# | This package will be uninstalled soon! |
# ...
#                                       \
#                                        \
#                                          ^__^
#                                          (oo)\_______
#                                          (__)\       )\/\
#                                              ||----w |
#                                              ||     ||

# %%
# Uninstall the package
# !pip uninstall -y cowsay
# Out:
# Found existing installation: cowsay 6.1
# Uninstalling cowsay-6.1:
#   Successfully uninstalled cowsay-6.1

# %% [markdown]
# ## 5. Using Requirements Files
#
# Requirements files help manage dependencies for a project in a reproducible way.

# %%
# # Create a requirements.txt file
# %%writefile requirements.txt
# numpy>=1.20.0,<2.0.0
# pandas==2.0.3
# matplotlib>=3.5.0
# scikit-learn==1.3.0

# %% [markdown]
# ```
#     numpy>=1.20.0,<2.0.0
#                ^
# SyntaxError: invalid syntax
# ```

# %%
# Create content for requirements.txt
requirements_content = '''numpy>=1.20.0,<2.0.0
pandas==2.0.3
matplotlib>=3.5.0
scikit-learn==1.3.0
'''

# Write the content to requirements.txt
with open('requirements.txt', 'w') as file:
    file.write(requirements_content)

# %%
# Install packages from requirements.txt
# (commented to prevent actual installation in this notebook)
# !pip install -r requirements.txt

# %% [markdown]
# ### Generating Requirements Files
#
# You can create requirements files from your current environment.

# %%
# Generate a requirements file from installed packages
# !pip freeze > current_requirements.txt

# Show the first 10 lines of the generated file
# !head -10 current_requirements.txt
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ```
# 'head' is not recognized as an internal or external command,
# operable program or batch file.
# ```

# %%
# Generate a requirements file from installed packages
# !pip freeze > current_requirements.txt

# Show the first 10 lines of the generated file using Python
with open('current_requirements.txt', 'r') as file:
    for i in range(10):
        print(file.readline().strip())
# Out:
# altair==5.5.0
# anyio==4.9.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==3.0.0
# async-lru==2.0.5
# attrs==25.3.0
# autopep8==2.3.2
# babel==2.17.0

# %% [markdown]
# ## 6. Working with Virtual Environments
#
# Virtual environments allow you to create isolated Python environments for different projects.
#
# ### Creating and Using Virtual Environments with venv
#
# Python's built-in `venv` module is the standard way to create virtual environments.

# %%
# Create a virtual environment (commands shown for reference)
# On Windows:
# !python -m venv my_project_env
# !my_project_env\Scripts\activate

# On macOS/Linux:
# !python -m venv my_project_env
# !source my_project_env/bin/activate

# %% [markdown]
# ### Managing Packages in a Virtual Environment
#
# Once activated, pip commands install packages to the virtual environment only.

# %%
# After activation (commands shown for reference)
# !pip install numpy pandas matplotlib
# !pip list
# !deactivate  # To exit the virtual environment

# %% [markdown]
# ### Using conda Environments
#
# If you're using Anaconda or Miniconda, you can use conda for environment management.

# %%
# Conda commands (shown for reference)
# !conda create -n data_science_env python=3.9
# !conda activate data_science_env
# !conda install numpy pandas matplotlib
# !conda deactivate

# %% [markdown]
# ## 7. Finding and Exploring Packages
#
# ### Searching for Packages
#
# You can search for packages directly with pip.

# %%
# # Search for packages related to 'data visualization'
# !pip search "data visualization" 2>/dev/null || echo "Note: pip search is deprecated. Use https://pypi.org instead."

# %% [markdown]
# ### Exploring Popular Python Packages
#
# Let's explore some of the most popular Python packages and their uses:

# %%
# Create a DataFrame of popular Python packages
import pandas as pd

popular_packages = [
    {"Package": "numpy", "Category": "Scientific Computing", "Description": "Numerical computing with arrays and matrices"},
    {"Package": "pandas", "Category": "Data Analysis", "Description": "Data manipulation and analysis"},
    {"Package": "matplotlib", "Category": "Visualization", "Description": "Creating static, animated, and interactive visualizations"},
    {"Package": "scikit-learn", "Category": "Machine Learning", "Description": "Tools for machine learning and data mining"},
    {"Package": "requests", "Category": "Networking", "Description": "HTTP library for making requests"},
    {"Package": "flask", "Category": "Web Development", "Description": "Lightweight web application framework"},
    {"Package": "django", "Category": "Web Development", "Description": "High-level web framework"},
    {"Package": "tensorflow", "Category": "Machine Learning", "Description": "Platform for machine learning and AI"},
    {"Package": "pytorch", "Category": "Machine Learning", "Description": "Machine learning library with GPU acceleration"},
    {"Package": "beautifulsoup4", "Category": "Web Scraping", "Description": "Library for parsing HTML and XML"}
]

df = pd.DataFrame(popular_packages)
df
# Out:
#           Package              Category  \
# 0           numpy  Scientific Computing
# 1          pandas         Data Analysis
# 2      matplotlib         Visualization
# 3    scikit-learn      Machine Learning
# 4        requests            Networking
# 5           flask       Web Development
# 6          django       Web Development
# 7      tensorflow      Machine Learning
# 8         pytorch      Machine Learning
# 9  beautifulsoup4          Web Scraping
#
#                                          Description
# 0       Numerical computing with arrays and matrices
# 1                     Data manipulation and analysis
# 2  Creating static, animated, and interactive vis...
# 3         Tools for machine learning and data mining
# 4                   HTTP library for making requests
# 5              Lightweight web application framework
# 6                           High-level web framework
# 7               Platform for machine learning and AI
# ...

# %% [markdown]
# ## 8. Creating and Publishing Packages
#
# ### Basic Package Structure
#
# A minimal Python package structure looks like this:

# %%
# Visualization of a package directory structure
package_structure = """
my_package/
├── my_package/
│   ├── __init__.py
│   ├── module1.py
│   └── module2.py
├── tests/
│   └── test_my_package.py
├── README.md
├── setup.py
└── LICENSE
"""

print(package_structure)
# Out:
# my_package/
# ├── my_package/
# │   ├── __init__.py
# │   ├── module1.py
# │   └── module2.py
# ├── tests/
# │   └── test_my_package.py
# ├── README.md
# ├── setup.py
# └── LICENSE

# %% [markdown]
# ### Creating a setup.py File
#
# The `setup.py` file defines metadata about your package.

# %%
# %%writefile sample_setup.py
from setuptools import setup, find_packages

setup(
    name="my_package",
    version="0.1.0",
    author="Your Name",
    author_email="your.email@example.com",
    description="A short description of your package",
    long_description=open("README.md").read(),
    long_description_content_type="text/markdown",
    url="https://github.com/yourusername/my_package",
    packages=find_packages(),
    classifiers=[
        "Programming Language :: Python :: 3",
        "License :: OSI Approved :: MIT License",
        "Operating System :: OS Independent",
    ],
    python_requires=">=3.6",
    install_requires=[
        "numpy>=1.18.0",
        "pandas>=1.0.0",
    ],
)
# Out:
# Writing sample_setup.py

# %% [markdown]
# ### Building and Publishing a Package
#
# These are the steps to build and publish a package to PyPI.

# %%
# Commands for building and publishing a package (for reference)
build_publish_commands = """
# Install required tools
pip install setuptools wheel twine

# Build the package
python setup.py sdist bdist_wheel

# Upload to PyPI test server (optional)
twine upload --repository-url https://test.pypi.org/legacy/ dist/*

# Upload to PyPI
twine upload dist/*
"""

print(build_publish_commands)
# Out:
# # Install required tools
# pip install setuptools wheel twine
#
# # Build the package
# python setup.py sdist bdist_wheel
#
# # Upload to PyPI test server (optional)
# twine upload --repository-url https://test.pypi.org/legacy/ dist/*
#
# # Upload to PyPI
# twine upload dist/*

# %% [markdown]
# ## 9. Common pip Commands and Options
#
# Here's a reference table of common pip commands and their options:

# %%
pip_commands = [
    {"Command": "pip install package_name", "Description": "Install a package"},
    {"Command": "pip install package_name==1.2.3", "Description": "Install a specific version"},
    {"Command": "pip install -U package_name", "Description": "Upgrade a package"},
    {"Command": "pip uninstall package_name", "Description": "Remove a package"},
    {"Command": "pip list", "Description": "List installed packages"},
    {"Command": "pip show package_name", "Description": "Show package details"},
    {"Command": "pip freeze", "Description": "Output installed packages in requirements format"},
    {"Command": "pip install -r requirements.txt", "Description": "Install from a requirements file"},
    {"Command": "pip download package_name", "Description": "Download a package without installing"},
    {"Command": "pip cache info", "Description": "Show pip cache information"},
    {"Command": "pip cache purge", "Description": "Remove all items from pip cache"},
    {"Command": "pip install --no-cache-dir package_name", "Description": "Install without using the cache"},
    {"Command": "pip install -e .", "Description": "Install current directory in editable mode"}
]

pd.DataFrame(pip_commands)
# Out:
#                                     Command  \
# 0                  pip install package_name
# 1           pip install package_name==1.2.3
# 2               pip install -U package_name
# 3                pip uninstall package_name
# 4                                  pip list
# 5                     pip show package_name
# 6                                pip freeze
# 7           pip install -r requirements.txt
# 8                 pip download package_name
# 9                            pip cache info
# 10                          pip cache purge
# 11  pip install --no-cache-dir package_name
# 12                         pip install -e .
#
#                                          Description
# 0                                  Install a package
# 1                         Install a specific version
# 2                                  Upgrade a package
# 3                                   Remove a package
# 4                            List installed packages
# ...

# %% [markdown]
# ## 10. Advanced Package Management
#
# ### Dependency Resolution
#
# pip automatically installs dependencies, but sometimes conflicts arise.

# %%
# Demonstrate dependency resolution (commented to avoid execution)
# !pip install tensorflow  # Will install numerous dependencies

# %% [markdown]
# ### Using pip-tools for Dependency Management
#
# `pip-tools` provides advanced dependency management with `pip-compile` and `pip-sync`.

# %%
# Install pip-tools
# !pip install pip-tools

# %%
# %%writefile requirements.in
# # High-level dependencies (without version constraints)
# numpy
# pandas
# matplotlib
# Out:
# Writing requirements.in

# %%
# Compile precise requirements (commented to avoid execution)
# !pip-compile requirements.in

# %% [markdown]
# ### Alternative Package Managers
#
# While pip is the standard, there are alternatives with different features:

# %%
alternative_managers = [
    {"Name": "conda", "Description": "Package, dependency and environment manager; handles binary packages"},
    {"Name": "pipenv", "Description": "Combines pip and virtualenv; provides a Pipfile for dependencies"},
    {"Name": "poetry", "Description": "Dependency management and packaging made easy"},
    {"Name": "pipx", "Description": "Install and run Python applications in isolated environments"}
]

pd.DataFrame(alternative_managers)
# Out:
#      Name                                        Description
# 0   conda  Package, dependency and environment manager; h...
# 1  pipenv  Combines pip and virtualenv; provides a Pipfil...
# 2  poetry      Dependency management and packaging made easy
# 3    pipx  Install and run Python applications in isolate...

# %% [markdown]
# ### Security Best Practices
#
# 1. Always verify the source of packages
# 2. Keep packages updated
# 3. Use dependency scanning tools
# 4. Pin dependencies for reproducibility

# %%
# Example of using safety to check for vulnerabilities
# !pip install safety
# !safety check

# %% [markdown]
# ## Summary
#
# In this notebook, we've covered:
#
# 1. **Understanding Python package management** - what packages are and why they're important
# 2. **Using pip** - the standard Python package manager
# 3. **Installing packages** - from PyPI and alternative sources
# 4. **Managing installed packages** - listing, updating, and uninstalling
# 5. **Working with requirements files** - for reproducible environments
# 6. **Virtual environments** - for isolated development spaces
# 7. **Finding packages** - discovering tools for your projects
# 8. **Creating and publishing packages** - sharing your code
# 9. **Common pip commands** - a reference guide
# 10. **Advanced techniques** - for more complex projects
#
# Effective package management is essential for Python development, ensuring projects are reliable, secure, and shareable.
